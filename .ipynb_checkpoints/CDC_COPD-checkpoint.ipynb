# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import re
import statsmodels.api as sm
from statsmodels.genmod.families import Poisson
from sklearn.model_selection import train_test_split
from sklearn import cluster, datasets
from sklearn.preprocessing import MinMaxScaler
from sklearn.ensemble import RandomForestRegressor
from sklearn import metrics
from sklearn.metrics import classification_report
from sklearn.linear_model import LinearRegression

# %%
Air_Qual = pd.read_csv('Air_Qual.csv')

Death_2012_1 = pd.read_csv('Underlying Cause of Death, 2012.txt',sep='\t', usecols = ["ICD Sub-Chapter","ICD Sub-Chapter Code","State","State Code","County","County Code","2013 Urbanization","2013 Urbanization Code","Five-Year Age Groups","Five-Year Age Groups Code","Deaths","Population","Crude Rate","% of Total Deaths"])
Death_2012_1['Year'] = 2012
Death_2013_1 = pd.read_csv('Underlying Cause of Death, 2013.txt',sep='\t', usecols = ["ICD Sub-Chapter","ICD Sub-Chapter Code","State","State Code","County","County Code","2013 Urbanization","2013 Urbanization Code","Five-Year Age Groups","Five-Year Age Groups Code","Deaths","Population","Crude Rate","% of Total Deaths"])
Death_2013_1['Year'] = 2013
Death_2014_1 = pd.read_csv('Underlying Cause of Death, 2014.txt',sep='\t', usecols = ["ICD Sub-Chapter","ICD Sub-Chapter Code","State","State Code","County","County Code","2013 Urbanization","2013 Urbanization Code","Five-Year Age Groups","Five-Year Age Groups Code","Deaths","Population","Crude Rate","% of Total Deaths"])
Death_2014_1['Year'] = 2014
Death_2015_1 = pd.read_csv('Underlying Cause of Death, 2015.txt',sep='\t', usecols = ["ICD Sub-Chapter","ICD Sub-Chapter Code","State","State Code","County","County Code","2013 Urbanization","2013 Urbanization Code","Five-Year Age Groups","Five-Year Age Groups Code","Deaths","Population","Crude Rate","% of Total Deaths"])
Death_2015_1['Year'] = 2015

# %% [markdown]
# # Table on Diabetes

# %%
Diabetes = pd.read_csv('Diabetes.csv',sep=',', usecols = ['State','County','Prevalence, 1999, Both Sexes',
'Prevalence, 2000, Both Sexes','Prevalence, 2001, Both Sexes','Prevalence, 2002, Both Sexes',
'Prevalence, 2003, Both Sexes','Prevalence, 2004, Both Sexes','Prevalence, 2005, Both Sexes', 
'Prevalence, 2006, Both Sexes','Prevalence, 2007, Both Sexes','Prevalence, 2008, Both Sexes',
'Prevalence, 2009, Both Sexes','Prevalence, 2010, Both Sexes','Prevalence, 2011, Both Sexes',
'Prevalence, 2012, Both Sexes'])  

pandas_dict = {}
Year_list = [(2000,'2000'),(2001,'2001'),(2002,'2002'),(2003,'2003'),(2004,'2004'),
             (2005,'2005'),(2006,'2006'),(2007,'2007'),(2008,'2008'),(2009,'2009'),
             (2010,'2010'),(2011,'2011'),(2012,'2012')]
for k,v in Year_list:
    pandas_dict[k] = Diabetes[['State','County','Prevalence, %r, Both Sexes' %k]]

Diabetes_list = []
Diabetes = pd.DataFrame()
for k,v in pandas_dict.items():
    v['Year'] = k
    v.columns.values[2] = 'Prevalence of Diabetes'
    Diabetes_list.append(v)
Diabetes_Concat = pd.concat(Diabetes_list)
Diabetes_Concat['County'] = Diabetes_Concat['County'].apply(lambda x: x.split()[0])

# %% [markdown]
# # Table on Poverty

# %%
import glob
import errno
import os
path = '/Users/jitsen/Documents/metis/metisgh/CDC/Poverty'
content = []
for filename in glob.glob(os.path.join(path, '*.csv')):
    content.append(filename)
    
Poverty = pd.read_csv(content[0],usecols = ['Year','State / County Name','All Ages in Poverty Percent',
                                           'Median Household Income in Dollars'])
for i in content[1:]:
    Poverty = pd.concat([Poverty, pd.read_csv(i,usecols = ['Year','State / County Name','All Ages in Poverty Percent',
                                                          'Median Household Income in Dollars'])])

# %%
Poverty['County'] = Poverty['State / County Name'].apply(lambda x : x.split()[0])
Poverty['State'] = Poverty['State / County Name'].apply(lambda x : x.split()[-1][1:3])
states = {'AK': 'Alaska','AL': 'Alabama','AR': 'Arkansas','AS': 'American Samoa','AZ': 'Arizona','CA': 'California','CO': 'Colorado',
        'CT': 'Connecticut','DC': 'District of Columbia','DE': 'Delaware','FL': 'Florida','GA': 'Georgia','GU': 'Guam',
        'HI': 'Hawaii','IA': 'Iowa','ID': 'Idaho','IL': 'Illinois','IN': 'Indiana','KS': 'Kansas','KY': 'Kentucky',
        'LA': 'Louisiana','MA': 'Massachusetts','MD': 'Maryland','ME': 'Maine','MI': 'Michigan','MN': 'Minnesota',
        'MO': 'Missouri','MP': 'Northern Mariana Islands','MS': 'Mississippi','MT': 'Montana','NA': 'National','NC': 'North Carolina',
        'ND': 'North Dakota','NE': 'Nebraska','NH': 'New Hampshire','NJ': 'New Jersey','NM': 'New Mexico','NV': 'Nevada',
        'NY': 'New York','OH': 'Ohio','OK': 'Oklahoma','OR': 'Oregon','PA': 'Pennsylvania','PR': 'Puerto Rico','RI': 'Rhode Island',
        'SC': 'South Carolina','SD': 'South Dakota','TN': 'Tennessee','TX': 'Texas','UT': 'Utah','VA': 'Virginia',
        'VI': 'Virgin Islands','VT': 'Vermont','WA': 'Washington','WI': 'Wisconsin','WV': 'West Virginia','WY': 'Wyoming'}

Poverty['State'] = Poverty['State'].map(states)

Poverty['Median_Income'] = Poverty['Median Household Income in Dollars'].apply(lambda x : re.sub('[^0-9]','',str(x)))
Poverty['Median_Income'] = pd.to_numeric(Poverty['Median_Income'], errors='coerce')

# %% [markdown]
# # Merge Tables on Diabetes and Poverty

# %%
Diabetes_Poverty= pd.merge(Diabetes_Concat, Poverty,left_on = ['County','Year','State'],
                  right_on = ['County','Year','State'])

# %% [markdown]
# # Checking if Intergerity if tables were preserved

# %%
Diabetes_Poverty['Year'].unique()
# Out:
# array([2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010,
#        2011, 2012])

# %%
Air_Qual_2_5 = Air_Qual[Air_Qual['MeasureId']==296]

# %%
Diabetes_Poverty_Air_Qual_2_5 = pd.merge(Diabetes_Poverty,Air_Qual_2_5,
                left_on = ['County','Year','State'], 
                                right_on = ['CountyName','ReportYear','StateName'])

# %%
Diabetes_Poverty_Air_Qual_2_5['Value_sq'] = Diabetes_Poverty_Air_Qual_2_5['Value'].apply(
lambda x: x**2 )

# %%
DPA_2008 = Diabetes_Poverty_Air_Qual_2_5[(Diabetes_Poverty_Air_Qual_2_5['ReportYear'] >= 2001)&
                                        (Diabetes_Poverty_Air_Qual_2_5['ReportYear'] <= 2008)]
DPA_2009 = Diabetes_Poverty_Air_Qual_2_5[(Diabetes_Poverty_Air_Qual_2_5['ReportYear'] >= 2002)&
                                        (Diabetes_Poverty_Air_Qual_2_5['ReportYear'] <= 2009)]
DPA_2010 = Diabetes_Poverty_Air_Qual_2_5[(Diabetes_Poverty_Air_Qual_2_5['ReportYear'] >= 2003)&
                                        (Diabetes_Poverty_Air_Qual_2_5['ReportYear'] <= 2010)]
DPA_2011 = Diabetes_Poverty_Air_Qual_2_5[(Diabetes_Poverty_Air_Qual_2_5['ReportYear'] >= 2004)&
                                        (Diabetes_Poverty_Air_Qual_2_5['ReportYear'] <= 2011)]

# %%
DPA_2008_mean = DPA_2008[['State', 'County', 'Prevalence of Diabetes', 'Year','State / County Name',
'Median_Income','All Ages in Poverty Percent','Value','Value_sq']].groupby(['State','County']).mean()
DPA_2008_mean = DPA_2008_mean.reset_index()
DPA_2008_mean['Comp_Year'] = 2012

DPA_2009_mean = DPA_2009[['State', 'County', 'Prevalence of Diabetes', 'Year','State / County Name',
'Median_Income','All Ages in Poverty Percent','Value','Value_sq']].groupby(['State','County']).mean()
DPA_2009_mean = DPA_2009_mean.reset_index()
DPA_2009_mean['Comp_Year'] = 2013

DPA_2010_mean = DPA_2010[['State', 'County', 'Prevalence of Diabetes', 'Year','State / County Name',
'Median_Income','All Ages in Poverty Percent','Value','Value_sq']].groupby(['State','County']).mean()
DPA_2010_mean = DPA_2010_mean.reset_index()
DPA_2010_mean['Comp_Year'] = 2014

DPA_2011_mean = DPA_2011[['State', 'County', 'Prevalence of Diabetes', 'Year','State / County Name',
'Median_Income','All Ages in Poverty Percent','Value','Value_sq']].groupby(['State','County']).mean()
DPA_2011_mean = DPA_2011_mean.reset_index()
DPA_2011_mean['Comp_Year'] = 2015

# %%
Death_concat = pd.concat([Death_2012_1,Death_2013_1,
               Death_2014_1,Death_2015_1])

Death_new = Death_concat[['State','County','2013 Urbanization','2013 Urbanization Code',
'Five-Year Age Groups','Deaths','Population','Year','ICD Sub-Chapter']]
Death_new['County'] = Death_new.County.str.split().str[0]
cols = ['State','County','2013 Urbanization','2013 Urbanization Code',
'Five-Year Age Groups','Deaths','Population','Year','ICD Sub-Chapter']
Death_new = Death_new.loc[:, cols].dropna()

DPA_concat = pd.concat([DPA_2008_mean,DPA_2009_mean,DPA_2010_mean,DPA_2011_mean])
# Out:
# /Users/jitsen/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
Death_DPA_merge = pd.merge(DPA_concat, Death_new,left_on = ['State','County','Comp_Year'],
                          right_on = ['State','County','Year'])

# %%
Death_DPA_merge = Death_DPA_merge[Death_DPA_merge['Population'] != 'Not Applicable']
Death_DPA_merge['Population'] = Death_DPA_merge['Population'].astype('int')
Death_DPA_merge['prop_death'] = Death_DPA_merge['Deaths']/Death_DPA_merge['Population']
Death_DPA_merge['Five-Year Age Groups'] = Death_DPA_merge['Five-Year Age Groups'].apply(
lambda x : (int(x[3:5])+int(x[0:2]))/2)
Death_DPA_merge
Death_DPA_merge_COPD = Death_DPA_merge[Death_DPA_merge['ICD Sub-Chapter'] == 'Chronic lower respiratory diseases']

# %%
Death_DPA_merge_COPD
# Out:
#            State      County  Prevalence of Diabetes  Year_x  Median_Income  \
# 11       Alabama     Baldwin                 8.02125  2004.5      44353.625
# 12       Alabama     Baldwin                 8.02125  2004.5      44353.625
# 17       Alabama      Blount                 9.48625  2004.5      40049.500
# 27       Alabama     Calhoun                10.75500  2004.5      35238.500
# 28       Alabama     Calhoun                10.75500  2004.5      35238.500
# 37       Alabama     Colbert                10.68250  2004.5      35292.125
# 38       Alabama     Colbert                10.68250  2004.5      35292.125
# 44       Alabama     Cullman                 9.15125  2004.5      35730.125
# 45       Alabama     Cullman                 9.15125  2004.5      35730.125
# 54       Alabama      DeKalb                10.02000  2004.5      32284.125
# 55       Alabama      DeKalb                10.02000  2004.5      32284.125
# 56       Alabama      DeKalb                10.02000  2004.5      32284.125
# 58       Alabama      Elmore                 9.49750  2004.5      45724.000
# 69       Alabama      Etowah                10.09000  2004.5      32919.250
# 70       Alabama      Etowah                10.09000  2004.5      32919.250
# 76       Alabama     Houston                 9.56375  2004.5      37491.625
# 81       Alabama     Jackson                 9.45625  2004.5      34246.125
# 95       Alabama   Jefferson                 9.89875  2004.5      40748.375
# 96       Alabama   Jefferson                 9.89875  2004.5      40748.375
# 97       Alabama   Jefferson                 9.89875  2004.5      40748.375
# 98       Alabama   Jefferson                 9.89875  2004.5      40748.375
# 99       Alabama   Jefferson                 9.89875  2004.5      40748.375
# 100      Alabama   Jefferson                 9.89875  2004.5      40748.375
# 107      Alabama  Lauderdale                 9.22500  2004.5      35508.375
# 108      Alabama  Lauderdale                 9.22500  2004.5      35508.375
# 109      Alabama  Lauderdale                 9.22500  2004.5      35508.375
# 112      Alabama         Lee                 9.94750  2004.5      35905.875
# 113      Alabama         Lee                 9.94750  2004.5      35905.875
# 117      Alabama   Limestone                 9.45500  2004.5      42245.625
# 128      Alabama     Madison                 8.97500  2004.5      50160.375
# ...          ...         ...                     ...     ...            ...
# 38569  Wisconsin   Manitowoc                 8.07500  2007.5      48077.875
# 38575  Wisconsin    Marathon                 7.60375  2007.5      51456.250
# 38592  Wisconsin   Milwaukee                 9.63250  2007.5      41386.625
# 38593  Wisconsin   Milwaukee                 9.63250  2007.5      41386.625
# 38594  Wisconsin   Milwaukee                 9.63250  2007.5      41386.625
# 38595  Wisconsin   Milwaukee                 9.63250  2007.5      41386.625
# 38596  Wisconsin   Milwaukee                 9.63250  2007.5      41386.625
# 38597  Wisconsin   Milwaukee                 9.63250  2007.5      41386.625
# 38609  Wisconsin   Outagamie                 7.68250  2007.5      55072.875
# 38610  Wisconsin   Outagamie                 7.68250  2007.5      55072.875
# 38611  Wisconsin   Outagamie                 7.68250  2007.5      55072.875
# 38612  Wisconsin   Outagamie                 7.68250  2007.5      55072.875
# 38631  Wisconsin      Racine                 8.83125  2007.5      52098.125
# 38632  Wisconsin      Racine                 8.83125  2007.5      52098.125
# 38633  Wisconsin      Racine                 8.83125  2007.5      52098.125
# 38644  Wisconsin        Rock                 8.34875  2007.5      48120.125
# 38645  Wisconsin        Rock                 8.34875  2007.5      48120.125
# 38646  Wisconsin        Rock                 8.34875  2007.5      48120.125
# 38687  Wisconsin    Waukesha                 6.10750  2007.5      71470.500
# 38688  Wisconsin    Waukesha                 6.10750  2007.5      71470.500
# 38689  Wisconsin    Waukesha                 6.10750  2007.5      71470.500
# 38690  Wisconsin    Waukesha                 6.10750  2007.5      71470.500
# 38707  Wisconsin   Winnebago                 7.89875  2007.5      49379.375
# 38708  Wisconsin   Winnebago                 7.89875  2007.5      49379.375
# 38709  Wisconsin   Winnebago                 7.89875  2007.5      49379.375
# 38721    Wyoming     Laramie                 7.60625  2007.5      50406.625
# 38722    Wyoming     Laramie                 7.60625  2007.5      50406.625
# 38730    Wyoming     Natrona                 7.63250  2007.5      49145.625
# 38731    Wyoming     Natrona                 7.63250  2007.5      49145.625
# 38732    Wyoming     Natrona                 7.63250  2007.5      49145.625
#
#        All Ages in Poverty Percent      Value    Value_sq  Comp_Year  \
# 11                         10.5625  11.530307  133.452176       2012
# 12                         10.5625  11.530307  133.452176       2012
# 17                         12.6125  15.069577  227.865066       2012
# 27                         16.8250  14.551696  212.497484       2012
# 28                         16.8250  14.551696  212.497484       2012
# 37                         14.6250  13.285461  176.851621       2012
# 38                         14.6250  13.285461  176.851621       2012
# 44                         14.3375  14.960389  224.562424       2012
# 45                         14.3375  14.960389  224.562424       2012
# 54                         17.1625  14.330971  205.960790       2012
# 55                         17.1625  14.330971  205.960790       2012
# 56                         17.1625  14.330971  205.960790       2012
# 58                         12.5125  13.410996  180.380538       2012
# 69                         16.4875  14.491170  210.922956       2012
# 70                         16.4875  14.491170  210.922956       2012
# 76                         15.5625  12.103505  146.975242       2012
# 81                         16.0375  13.978806  196.004979       2012
# 95                         14.5375  19.243976  372.162937       2012
# 96                         14.5375  19.243976  372.162937       2012
# 97                         14.5375  19.243976  372.162937       2012
# 98                         14.5375  19.243976  372.162937       2012
# 99                         14.5375  19.243976  372.162937       2012
# 100                        14.5375  19.243976  372.162937       2012
# 107                        16.5375  13.603105  185.409034       2012
# 108                        16.5375  13.603105  185.409034       2012
# 109                        16.5375  13.603105  185.409034       2012
# 112                        16.7625  13.480373  182.465601       2012
# 113                        16.7625  13.480373  182.465601       2012
# 117                        12.6750  14.238274  203.225620       2012
# 128                        10.9375  14.058043  198.368628       2012
# ...                            ...        ...         ...        ...
# 38569                       8.8125  10.729097  115.511075       2015
# 38575                       9.1125   9.806848   96.442972       2015
# 38592                      19.6250  12.931593  168.954307       2015
# 38593                      19.6250  12.931593  168.954307       2015
# 38594                      19.6250  12.931593  168.954307       2015
# 38595                      19.6250  12.931593  168.954307       2015
# 38596                      19.6250  12.931593  168.954307       2015
# 38597                      19.6250  12.931593  168.954307       2015
# 38609                       7.6250  11.113996  123.949545       2015
# 38610                       7.6250  11.113996  123.949545       2015
# 38611                       7.6250  11.113996  123.949545       2015
# 38612                       7.6250  11.113996  123.949545       2015
# 38631                      11.5625  12.491334  157.123575       2015
# 38632                      11.5625  12.491334  157.123575       2015
# 38633                      11.5625  12.491334  157.123575       2015
# 38644                      11.6625  12.164173  148.827284       2015
# 38645                      11.6625  12.164173  148.827284       2015
# 38646                      11.6625  12.164173  148.827284       2015
# 38687                       4.6625  12.584788  159.556586       2015
# 38688                       4.6625  12.584788  159.556586       2015
# 38689                       4.6625  12.584788  159.556586       2015
# 38690                       4.6625  12.584788  159.556586       2015
# 38707                      10.2000  11.321069  128.585291       2015
# 38708                      10.2000  11.321069  128.585291       2015
# 38709                      10.2000  11.321069  128.585291       2015
# 38721                       9.9750   6.109476   37.369435       2015
# 38722                       9.9750   6.109476   37.369435       2015
# 38730                      10.3875   6.114545   37.458473       2015
# 38731                      10.3875   6.114545   37.458473       2015
# 38732                      10.3875   6.114545   37.458473       2015
#
#               2013 Urbanization  2013 Urbanization Code  Five-Year Age Groups  \
# 11                  Small Metro                     4.0                  77.0
# 12                  Small Metro                     4.0                  82.0
# 17           Large Fringe Metro                     2.0                  67.0
# 27                  Small Metro                     4.0                  62.0
# 28                  Small Metro                     4.0                  77.0
# 37                  Small Metro                     4.0                  72.0
# 38                  Small Metro                     4.0                  82.0
# 44     Micropolitan (non-metro)                     5.0                  67.0
# 45     Micropolitan (non-metro)                     5.0                  82.0
# 54          NonCore (non-metro)                     6.0                  67.0
# 55          NonCore (non-metro)                     6.0                  77.0
# 56          NonCore (non-metro)                     6.0                  82.0
# 58                 Medium Metro                     3.0                  72.0
# 69                  Small Metro                     4.0                  72.0
# 70                  Small Metro                     4.0                  77.0
# 76                  Small Metro                     4.0                  77.0
# 81     Micropolitan (non-metro)                     5.0                  72.0
# 95          Large Central Metro                     1.0                  57.0
# 96          Large Central Metro                     1.0                  62.0
# 97          Large Central Metro                     1.0                  67.0
# 98          Large Central Metro                     1.0                  72.0
# 99          Large Central Metro                     1.0                  77.0
# 100         Large Central Metro                     1.0                  82.0
# 107                 Small Metro                     4.0                  72.0
# 108                 Small Metro                     4.0                  77.0
# 109                 Small Metro                     4.0                  82.0
# 112                 Small Metro                     4.0                  67.0
# 113                 Small Metro                     4.0                  82.0
# 117                Medium Metro                     3.0                  72.0
# 128                Medium Metro                     3.0                  62.0
# ...                         ...                     ...                   ...
# 38569  Micropolitan (non-metro)                     5.0                  82.0
# 38575               Small Metro                     4.0                  82.0
# 38592       Large Central Metro                     1.0                  57.0
# 38593       Large Central Metro                     1.0                  62.0
# 38594       Large Central Metro                     1.0                  67.0
# 38595       Large Central Metro                     1.0                  72.0
# 38596       Large Central Metro                     1.0                  77.0
# 38597       Large Central Metro                     1.0                  82.0
# 38609               Small Metro                     4.0                  67.0
# 38610               Small Metro                     4.0                  72.0
# 38611               Small Metro                     4.0                  77.0
# 38612               Small Metro                     4.0                  82.0
# 38631               Small Metro                     4.0                  72.0
# 38632               Small Metro                     4.0                  77.0
# 38633               Small Metro                     4.0                  82.0
# 38644               Small Metro                     4.0                  72.0
# 38645               Small Metro                     4.0                  77.0
# 38646               Small Metro                     4.0                  82.0
# 38687        Large Fringe Metro                     2.0                  67.0
# 38688        Large Fringe Metro                     2.0                  72.0
# 38689        Large Fringe Metro                     2.0                  77.0
# 38690        Large Fringe Metro                     2.0                  82.0
# 38707               Small Metro                     4.0                  72.0
# 38708               Small Metro                     4.0                  77.0
# 38709               Small Metro                     4.0                  82.0
# 38721               Small Metro                     4.0                  77.0
# 38722               Small Metro                     4.0                  82.0
# 38730               Small Metro                     4.0                  67.0
# 38731               Small Metro                     4.0                  72.0
# 38732               Small Metro                     4.0                  82.0
#
#        Deaths  Population  Year_y                     ICD Sub-Chapter  \
# 11       13.0        6071    2012  Chronic lower respiratory diseases
# 12       17.0        4114    2012  Chronic lower respiratory diseases
# 17       10.0        3163    2012  Chronic lower respiratory diseases
# 27       10.0        7314    2012  Chronic lower respiratory diseases
# 28       12.0        3358    2012  Chronic lower respiratory diseases
# 37       10.0        2378    2012  Chronic lower respiratory diseases
# 38       11.0        1265    2012  Chronic lower respiratory diseases
# 44       10.0        4542    2012  Chronic lower respiratory diseases
# 45       13.0        1706    2012  Chronic lower respiratory diseases
# 54       11.0        3549    2012  Chronic lower respiratory diseases
# 55       12.0        1933    2012  Chronic lower respiratory diseases
# 56       14.0        1346    2012  Chronic lower respiratory diseases
# 58       10.0        2619    2012  Chronic lower respiratory diseases
# 69       14.0        4159    2012  Chronic lower respiratory diseases
# 70       21.0        3092    2012  Chronic lower respiratory diseases
# 76       10.0        2891    2012  Chronic lower respiratory diseases
# 81       11.0        2364    2012  Chronic lower respiratory diseases
# 95       13.0       46364    2012  Chronic lower respiratory diseases
# 96       23.0       39096    2012  Chronic lower respiratory diseases
# 97       32.0       27715    2012  Chronic lower respiratory diseases
# 98       42.0       20088    2012  Chronic lower respiratory diseases
# 99       45.0       15460    2012  Chronic lower respiratory diseases
# 100      47.0       13146    2012  Chronic lower respiratory diseases
# 107      11.0        3984    2012  Chronic lower respiratory diseases
# 108      11.0        3052    2012  Chronic lower respiratory diseases
# 109      12.0        2215    2012  Chronic lower respiratory diseases
# 112      13.0        5154    2012  Chronic lower respiratory diseases
# 113      11.0        1708    2012  Chronic lower respiratory diseases
# 117      11.0        2891    2012  Chronic lower respiratory diseases
# 128      10.0       18415    2012  Chronic lower respiratory diseases
# ...       ...         ...     ...                                 ...
# 38569    10.0        1980    2015  Chronic lower respiratory diseases
# 38575    13.0        2913    2015  Chronic lower respiratory diseases
# 38592    13.0       61509    2015  Chronic lower respiratory diseases
# 38593    32.0       53226    2015  Chronic lower respiratory diseases
# 38594    51.0       39763    2015  Chronic lower respiratory diseases
# 38595    46.0       25329    2015  Chronic lower respiratory diseases
# 38596    41.0       18872    2015  Chronic lower respiratory diseases
# 38597    54.0       15392    2015  Chronic lower respiratory diseases
# 38609    14.0        8294    2015  Chronic lower respiratory diseases
# 38610    17.0        5912    2015  Chronic lower respiratory diseases
# 38611    11.0        4212    2015  Chronic lower respiratory diseases
# 38612    10.0        3040    2015  Chronic lower respiratory diseases
# 38631    15.0        6943    2015  Chronic lower respiratory diseases
# 38632    18.0        5073    2015  Chronic lower respiratory diseases
# 38633    19.0        3552    2015  Chronic lower respiratory diseases
# 38644    11.0        5872    2015  Chronic lower respiratory diseases
# 38645    11.0        4462    2015  Chronic lower respiratory diseases
# 38646    10.0        3192    2015  Chronic lower respiratory diseases
# 38687    13.0       22349    2015  Chronic lower respiratory diseases
# 38688    19.0       15365    2015  Chronic lower respiratory diseases
# 38689    16.0       11042    2015  Chronic lower respiratory diseases
# 38690    28.0        8826    2015  Chronic lower respiratory diseases
# 38707    12.0        5763    2015  Chronic lower respiratory diseases
# 38708    14.0        4332    2015  Chronic lower respiratory diseases
# 38709    10.0        3400    2015  Chronic lower respiratory diseases
# 38721    11.0        2309    2015  Chronic lower respiratory diseases
# 38722    12.0        1704    2015  Chronic lower respiratory diseases
# 38730    10.0        3758    2015  Chronic lower respiratory diseases
# 38731    17.0        2394    2015  Chronic lower respiratory diseases
# 38732    10.0        1312    2015  Chronic lower respiratory diseases
#
#        prop_death
# 11       0.002141
# 12       0.004132
# 17       0.003162
# 27       0.001367
# 28       0.003574
# 37       0.004205
# 38       0.008696
# 44       0.002202
# 45       0.007620
# 54       0.003099
# 55       0.006208
# 56       0.010401
# 58       0.003818
# 69       0.003366
# 70       0.006792
# 76       0.003459
# 81       0.004653
# 95       0.000280
# 96       0.000588
# 97       0.001155
# 98       0.002091
# 99       0.002911
# 100      0.003575
# 107      0.002761
# 108      0.003604
# 109      0.005418
# 112      0.002522
# 113      0.006440
# 117      0.003805
# 128      0.000543
# ...           ...
# 38569    0.005051
# 38575    0.004463
# 38592    0.000211
# 38593    0.000601
# 38594    0.001283
# 38595    0.001816
# 38596    0.002173
# 38597    0.003508
# 38609    0.001688
# 38610    0.002876
# 38611    0.002612
# 38612    0.003289
# 38631    0.002160
# 38632    0.003548
# 38633    0.005349
# 38644    0.001873
# 38645    0.002465
# 38646    0.003133
# 38687    0.000582
# 38688    0.001237
# 38689    0.001449
# 38690    0.003172
# 38707    0.002082
# 38708    0.003232
# 38709    0.002941
# 38721    0.004764
# 38722    0.007042
# 38730    0.002661
# 38731    0.007101
# 38732    0.007622
#
# [8504 rows x 17 columns]

# %%
Geo_coord = pd.read_csv('zip_codes_states.csv')
Geo_coord['state'] = Geo_coord['state'].map(states)
Geo_coord_mean = Geo_coord.groupby(['state','county',]).mean()
Geo_coord_mean = Geo_coord_mean.reset_index()
Death_m_concat_geo = pd.merge(Death_DPA_merge_COPD,Geo_coord_mean, left_on = ['State','County'],
                              right_on = ['state','county'])
Death_m_concat_geo
# Out:
#                State      County  Prevalence of Diabetes  Year_x  \
# 0            Alabama     Baldwin                 8.02125  2004.5
# 1            Alabama     Baldwin                 8.02125  2004.5
# 2            Alabama     Baldwin                 8.28875  2005.5
# 3            Alabama     Baldwin                 8.28875  2005.5
# 4            Alabama     Baldwin                 8.28875  2005.5
# 5            Alabama     Baldwin                 8.28875  2005.5
# 6            Alabama     Baldwin                 8.53875  2006.5
# 7            Alabama     Baldwin                 8.53875  2006.5
# 8            Alabama     Baldwin                 8.53875  2006.5
# 9            Alabama     Baldwin                 8.76250  2007.5
# 10           Alabama     Baldwin                 8.76250  2007.5
# 11           Alabama     Baldwin                 8.76250  2007.5
# 12           Alabama     Baldwin                 8.76250  2007.5
# 13           Alabama     Baldwin                 8.76250  2007.5
# 14           Alabama      Blount                 9.48625  2004.5
# 15           Alabama      Blount                 9.77375  2005.5
# 16           Alabama      Blount                10.24625  2007.5
# 17           Alabama     Calhoun                10.75500  2004.5
# 18           Alabama     Calhoun                10.75500  2004.5
# 19           Alabama     Calhoun                11.03750  2005.5
# 20           Alabama     Calhoun                11.03750  2005.5
# 21           Alabama     Calhoun                11.03750  2005.5
# 22           Alabama     Calhoun                11.03750  2005.5
# 23           Alabama     Calhoun                11.32625  2006.5
# 24           Alabama     Calhoun                11.32625  2006.5
# 25           Alabama     Calhoun                11.54250  2007.5
# 26           Alabama     Calhoun                11.54250  2007.5
# 27           Alabama     Calhoun                11.54250  2007.5
# 28           Alabama     Calhoun                11.54250  2007.5
# 29           Alabama     Calhoun                11.54250  2007.5
# ...              ...         ...                     ...     ...
# 8330        New York    Allegany                 9.04125  2007.5
# 8331        New York    Chenango                 8.61500  2007.5
# 8332  North Carolina    Carteret                 8.79250  2007.5
# 8333  North Carolina      Duplin                12.12000  2007.5
# 8334            Ohio       Brown                10.45250  2007.5
# 8335            Ohio     Hancock                 9.16250  2007.5
# 8336            Ohio     Hancock                 9.16250  2007.5
# 8337            Ohio       Huron                 9.56625  2007.5
# 8338            Ohio  Washington                10.10625  2007.5
# 8339            Ohio  Washington                10.10625  2007.5
# 8340        Oklahoma    Delaware                10.62000  2007.5
# 8341        Oklahoma    Delaware                10.62000  2007.5
# 8342        Oklahoma       Payne                 9.36750  2007.5
# 8343          Oregon        Polk                 8.29625  2007.5
# 8344          Oregon    Umatilla                 9.47875  2007.5
# 8345          Oregon     Yamhill                 8.41125  2007.5
# 8346          Oregon     Yamhill                 8.41125  2007.5
# 8347    Pennsylvania      Greene                 9.96375  2007.5
# 8348  South Carolina  Orangeburg                13.75125  2007.5
# 8349       Tennessee      Gibson                11.11000  2007.5
# 8350       Tennessee     Madison                10.75250  2007.5
# 8351       Tennessee      Tipton                10.52750  2007.5
# 8352           Texas      Fannin                 9.63125  2007.5
# 8353           Texas  Hutchinson                 9.53875  2007.5
# 8354           Texas        Kerr                 8.70875  2007.5
# 8355           Texas        Kerr                 8.70875  2007.5
# 8356           Texas      Upshur                 9.76375  2007.5
# 8357        Virginia     Bedford                 9.24875  2007.5
# 8358        Virginia   Frederick                 8.72500  2007.5
# 8359      Washington      Chelan                 7.54000  2007.5
#
#       Median_Income  All Ages in Poverty Percent      Value    Value_sq  \
# 0         44353.625                     10.56250  11.530307  133.452176
# 1         44353.625                     10.56250  11.530307  133.452176
# 2         45382.500                     10.83750  11.197984  126.490542
# 3         45382.500                     10.83750  11.197984  126.490542
# 4         45382.500                     10.83750  11.197984  126.490542
# 5         45382.500                     10.83750  11.197984  126.490542
# 6         46232.500                     11.16250  11.064917  123.770825
# 7         46232.500                     11.16250  11.064917  123.770825
# 8         46232.500                     11.16250  11.064917  123.770825
# 9         47255.375                     11.57500  10.749283  116.913935
# 10        47255.375                     11.57500  10.749283  116.913935
# 11        47255.375                     11.57500  10.749283  116.913935
# 12        47255.375                     11.57500  10.749283  116.913935
# 13        47255.375                     11.57500  10.749283  116.913935
# 14        40049.500                     12.61250  15.069577  227.865066
# 15        40717.625                     12.73750  14.429354  210.614947
# 16        42055.375                     13.60000  13.740712  192.401855
# 17        35238.500                     16.82500  14.551696  212.497484
# 18        35238.500                     16.82500  14.551696  212.497484
# 19        35924.875                     17.16250  14.032402  198.863843
# 20        35924.875                     17.16250  14.032402  198.863843
# 21        35924.875                     17.16250  14.032402  198.863843
# 22        35924.875                     17.16250  14.032402  198.863843
# 23        36662.750                     18.12500  13.840577  193.796462
# 24        36662.750                     18.12500  13.840577  193.796462
# 25        37403.125                     18.68750  13.630346  188.309616
# 26        37403.125                     18.68750  13.630346  188.309616
# 27        37403.125                     18.68750  13.630346  188.309616
# 28        37403.125                     18.68750  13.630346  188.309616
# 29        37403.125                     18.68750  13.630346  188.309616
# ...             ...                          ...        ...         ...
# 8330      38469.500                     16.85000   9.707575   95.542873
# 8331      40404.500                     14.31250   9.435311   90.535716
# 8332      44577.500                     13.13750   9.466071   89.938236
# 8333      33706.000                     21.11250  11.401462  131.271112
# 8334      42829.625                     13.52500  13.227832  176.639475
# 8335      48458.125                     10.38750  13.220606  176.704234
# 8336      48458.125                     10.38750  13.220606  176.704234
# 8337      45381.000                     12.16250  12.972214  170.168957
# 8338      39665.750                     14.36250  14.210277  204.143051
# 8339      39665.750                     14.36250  14.210277  204.143051
# 8340      33379.500                     19.83750  11.052450  122.587478
# 8341      33379.500                     19.83750  11.052450  122.587478
# 8342      35170.125                     21.33750  10.077238  101.979330
# 8343      49323.625                     13.20000   9.633026   94.687542
# 8344      42615.625                     15.78750   8.478086   72.290798
# 8345      50248.375                     12.85000   9.780171   97.726788
# 8346      50248.375                     12.85000   9.780171   97.726788
# 8347      37563.500                     17.15000  13.440915  183.014494
# 8348      32042.500                     24.36250  12.485241  157.678976
# 8349      34750.875                     17.42500  11.767403  140.314836
# 8350      40058.500                     18.10000  11.659364  138.086723
# 8351      48242.125                     14.65000  11.821672  141.860532
# 8352      39634.500                     16.48750  10.360698  107.928824
# 8353      44166.750                     12.97500   7.572181   57.353067
# 8354      41527.000                     14.67500   8.206658   67.492393
# 8355      41527.000                     14.67500   8.206658   67.492393
# 8356      40254.000                     15.52500  10.911485  120.043958
# 8357      43429.750                     13.08125  11.966125  145.735802
# 8358      60233.625                      7.35000  11.945372  144.893971
# 8359      44843.375                     13.41250   7.774208   62.284751
#
#       Comp_Year         2013 Urbanization     ...      Deaths  Population  \
# 0          2012               Small Metro     ...        13.0        6071
# 1          2012               Small Metro     ...        17.0        4114
# 2          2013               Small Metro     ...        17.0       11961
# 3          2013               Small Metro     ...        18.0        9160
# 4          2013               Small Metro     ...        14.0        6465
# 5          2013               Small Metro     ...        14.0        4132
# 6          2014               Small Metro     ...        11.0        9846
# 7          2014               Small Metro     ...        12.0        6815
# 8          2014               Small Metro     ...        21.0        4243
# 9          2015               Small Metro     ...        10.0       13846
# 10         2015               Small Metro     ...        12.0       13239
# 11         2015               Small Metro     ...        24.0       10366
# 12         2015               Small Metro     ...        13.0        7016
# 13         2015               Small Metro     ...        24.0        4436
# 14         2012        Large Fringe Metro     ...        10.0        3163
# 15         2013        Large Fringe Metro     ...        10.0        3235
# 16         2015        Large Fringe Metro     ...        11.0        1866
# 17         2012               Small Metro     ...        10.0        7314
# 18         2012               Small Metro     ...        12.0        3358
# 19         2013               Small Metro     ...        12.0        6032
# 20         2013               Small Metro     ...        14.0        4402
# 21         2013               Small Metro     ...        11.0        3403
# 22         2013               Small Metro     ...        14.0        2358
# 23         2014               Small Metro     ...        15.0        4551
# 24         2014               Small Metro     ...        18.0        3281
# 25         2015               Small Metro     ...        13.0        7611
# 26         2015               Small Metro     ...        13.0        6522
# 27         2015               Small Metro     ...        16.0        4640
# 28         2015               Small Metro     ...        14.0        3314
# 29         2015               Small Metro     ...        14.0        2388
# ...         ...                       ...     ...         ...         ...
# 8330       2015       NonCore (non-metro)     ...        12.0        1081
# 8331       2015       NonCore (non-metro)     ...        10.0        1648
# 8332       2015  Micropolitan (non-metro)     ...        11.0        2626
# 8333       2015       NonCore (non-metro)     ...        10.0        2399
# 8334       2015        Large Fringe Metro     ...        12.0        1424
# 8335       2015  Micropolitan (non-metro)     ...        12.0        2890
# 8336       2015  Micropolitan (non-metro)     ...        10.0        1541
# 8337       2015  Micropolitan (non-metro)     ...        10.0        2246
# 8338       2015  Micropolitan (non-metro)     ...        15.0        2243
# 8339       2015  Micropolitan (non-metro)     ...        13.0        1495
# 8340       2015       NonCore (non-metro)     ...        12.0        2627
# 8341       2015       NonCore (non-metro)     ...        11.0        1015
# 8342       2015  Micropolitan (non-metro)     ...        10.0        2879
# 8343       2015              Medium Metro     ...        10.0        2330
# 8344       2015  Micropolitan (non-metro)     ...        12.0        1914
# 8345       2015        Large Fringe Metro     ...        11.0        3987
# 8346       2015        Large Fringe Metro     ...        14.0        2642
# 8347       2015       NonCore (non-metro)     ...        12.0        1060
# 8348       2015  Micropolitan (non-metro)     ...        11.0        1839
# 8349       2015       NonCore (non-metro)     ...        10.0        1587
# 8350       2015               Small Metro     ...        10.0        2590
# 8351       2015        Large Fringe Metro     ...        11.0        1457
# 8352       2015       NonCore (non-metro)     ...        12.0        1639
# 8353       2015  Micropolitan (non-metro)     ...        10.0         461
# 8354       2015  Micropolitan (non-metro)     ...        12.0        3322
# 8355       2015  Micropolitan (non-metro)     ...        11.0        1866
# 8356       2015               Small Metro     ...        11.0         869
# 8357       2015              Medium Metro     ...        10.0        4123
# 8358       2015               Small Metro     ...        10.0        1551
# 8359       2015               Small Metro     ...        11.0        1647
#
#       Year_y                     ICD Sub-Chapter  prop_death           state  \
# 0       2012  Chronic lower respiratory diseases    0.002141         Alabama
# 1       2012  Chronic lower respiratory diseases    0.004132         Alabama
# 2       2013  Chronic lower respiratory diseases    0.001421         Alabama
# 3       2013  Chronic lower respiratory diseases    0.001965         Alabama
# 4       2013  Chronic lower respiratory diseases    0.002166         Alabama
# 5       2013  Chronic lower respiratory diseases    0.003388         Alabama
# 6       2014  Chronic lower respiratory diseases    0.001117         Alabama
# 7       2014  Chronic lower respiratory diseases    0.001761         Alabama
# 8       2014  Chronic lower respiratory diseases    0.004949         Alabama
# 9       2015  Chronic lower respiratory diseases    0.000722         Alabama
# 10      2015  Chronic lower respiratory diseases    0.000906         Alabama
# 11      2015  Chronic lower respiratory diseases    0.002315         Alabama
# 12      2015  Chronic lower respiratory diseases    0.001853         Alabama
# 13      2015  Chronic lower respiratory diseases    0.005410         Alabama
# 14      2012  Chronic lower respiratory diseases    0.003162         Alabama
# 15      2013  Chronic lower respiratory diseases    0.003091         Alabama
# 16      2015  Chronic lower respiratory diseases    0.005895         Alabama
# 17      2012  Chronic lower respiratory diseases    0.001367         Alabama
# 18      2012  Chronic lower respiratory diseases    0.003574         Alabama
# 19      2013  Chronic lower respiratory diseases    0.001989         Alabama
# 20      2013  Chronic lower respiratory diseases    0.003180         Alabama
# 21      2013  Chronic lower respiratory diseases    0.003232         Alabama
# 22      2013  Chronic lower respiratory diseases    0.005937         Alabama
# 23      2014  Chronic lower respiratory diseases    0.003296         Alabama
# 24      2014  Chronic lower respiratory diseases    0.005486         Alabama
# 25      2015  Chronic lower respiratory diseases    0.001708         Alabama
# 26      2015  Chronic lower respiratory diseases    0.001993         Alabama
# 27      2015  Chronic lower respiratory diseases    0.003448         Alabama
# 28      2015  Chronic lower respiratory diseases    0.004225         Alabama
# 29      2015  Chronic lower respiratory diseases    0.005863         Alabama
# ...      ...                                 ...         ...             ...
# 8330    2015  Chronic lower respiratory diseases    0.011101        New York
# 8331    2015  Chronic lower respiratory diseases    0.006068        New York
# 8332    2015  Chronic lower respiratory diseases    0.004189  North Carolina
# 8333    2015  Chronic lower respiratory diseases    0.004168  North Carolina
# 8334    2015  Chronic lower respiratory diseases    0.008427            Ohio
# 8335    2015  Chronic lower respiratory diseases    0.004152            Ohio
# 8336    2015  Chronic lower respiratory diseases    0.006489            Ohio
# 8337    2015  Chronic lower respiratory diseases    0.004452            Ohio
# 8338    2015  Chronic lower respiratory diseases    0.006687            Ohio
# 8339    2015  Chronic lower respiratory diseases    0.008696            Ohio
# 8340    2015  Chronic lower respiratory diseases    0.004568        Oklahoma
# 8341    2015  Chronic lower respiratory diseases    0.010837        Oklahoma
# 8342    2015  Chronic lower respiratory diseases    0.003473        Oklahoma
# 8343    2015  Chronic lower respiratory diseases    0.004292          Oregon
# 8344    2015  Chronic lower respiratory diseases    0.006270          Oregon
# 8345    2015  Chronic lower respiratory diseases    0.002759          Oregon
# 8346    2015  Chronic lower respiratory diseases    0.005299          Oregon
# 8347    2015  Chronic lower respiratory diseases    0.011321    Pennsylvania
# 8348    2015  Chronic lower respiratory diseases    0.005982  South Carolina
# 8349    2015  Chronic lower respiratory diseases    0.006301       Tennessee
# 8350    2015  Chronic lower respiratory diseases    0.003861       Tennessee
# 8351    2015  Chronic lower respiratory diseases    0.007550       Tennessee
# 8352    2015  Chronic lower respiratory diseases    0.007322           Texas
# 8353    2015  Chronic lower respiratory diseases    0.021692           Texas
# 8354    2015  Chronic lower respiratory diseases    0.003612           Texas
# 8355    2015  Chronic lower respiratory diseases    0.005895           Texas
# 8356    2015  Chronic lower respiratory diseases    0.012658           Texas
# 8357    2015  Chronic lower respiratory diseases    0.002425        Virginia
# 8358    2015  Chronic lower respiratory diseases    0.006447        Virginia
# 8359    2015  Chronic lower respiratory diseases    0.006679      Washington
#
#           county      zip_code   latitude   longitude
# 0        Baldwin  36550.307692  30.587202  -87.719056
# 1        Baldwin  36550.307692  30.587202  -87.719056
# 2        Baldwin  36550.307692  30.587202  -87.719056
# 3        Baldwin  36550.307692  30.587202  -87.719056
# 4        Baldwin  36550.307692  30.587202  -87.719056
# 5        Baldwin  36550.307692  30.587202  -87.719056
# 6        Baldwin  36550.307692  30.587202  -87.719056
# 7        Baldwin  36550.307692  30.587202  -87.719056
# 8        Baldwin  36550.307692  30.587202  -87.719056
# 9        Baldwin  36550.307692  30.587202  -87.719056
# 10       Baldwin  36550.307692  30.587202  -87.719056
# 11       Baldwin  36550.307692  30.587202  -87.719056
# 12       Baldwin  36550.307692  30.587202  -87.719056
# 13       Baldwin  36550.307692  30.587202  -87.719056
# 14        Blount  35074.714286  33.951944  -86.582932
# 15        Blount  35074.714286  33.951944  -86.582932
# 16        Blount  35074.714286  33.951944  -86.582932
# 17       Calhoun  36239.176471  33.767305  -85.830041
# 18       Calhoun  36239.176471  33.767305  -85.830041
# 19       Calhoun  36239.176471  33.767305  -85.830041
# 20       Calhoun  36239.176471  33.767305  -85.830041
# 21       Calhoun  36239.176471  33.767305  -85.830041
# 22       Calhoun  36239.176471  33.767305  -85.830041
# 23       Calhoun  36239.176471  33.767305  -85.830041
# 24       Calhoun  36239.176471  33.767305  -85.830041
# 25       Calhoun  36239.176471  33.767305  -85.830041
# 26       Calhoun  36239.176471  33.767305  -85.830041
# 27       Calhoun  36239.176471  33.767305  -85.830041
# 28       Calhoun  36239.176471  33.767305  -85.830041
# 29       Calhoun  36239.176471  33.767305  -85.830041
# ...          ...           ...        ...         ...
# 8330    Allegany  14747.071429  42.242917  -78.061252
# 8331    Chenango  13609.954545  42.529632  -75.604709
# 8332    Carteret  28552.882353  34.833658  -76.642526
# 8333      Duplin  28436.454545  34.948834  -77.952606
# 8334       Brown  45147.500000  38.905240  -83.866937
# 8335     Hancock  45777.230769  40.980605  -83.668738
# 8336     Hancock  45777.230769  40.980605  -83.668738
# 8337       Huron  44854.636364  41.149245  -82.592901
# 8338  Washington  45749.850000  39.456498  -81.443954
# 8339  Washington  45749.850000  39.456498  -81.443954
# 8340    Delaware  74348.625000  36.393128  -94.762452
# 8341    Delaware  74348.625000  36.393128  -94.762452
# 8342       Payne  74064.100000  36.109444  -96.969033
# 8343        Polk  97345.142857  44.926154 -123.323903
# 8344    Umatilla  97846.857143  45.706636 -118.721604
# 8345     Yamhill  97175.000000  45.225601 -123.198148
# 8346     Yamhill  97175.000000  45.225601 -123.198148
# 8347      Greene  15342.750000  39.872997  -80.113246
# 8348  Orangeburg  29114.611111  33.442425  -80.799305
# 8349      Gibson  38340.833333  35.998976  -88.933731
# 8350     Madison  38337.769231  35.597420  -88.835562
# 8351      Tipton  38031.250000  35.475200  -89.744757
# 8352      Fannin  75456.333333  33.522968  -96.153719
# 8353  Hutchinson  79042.400000  35.703772 -101.536613
# 8354        Kerr  78029.000000  30.046238  -99.226690
# 8355        Kerr  78029.000000  30.046238  -99.226690
# 8356      Upshur  75673.400000  32.721616  -94.860335
# 8357     Bedford  24302.833333  37.325418  -79.540283
# 8358   Frederick  22632.818182  39.202880  -78.240942
# 8359      Chelan  98823.571429  47.690383 -120.365872
#
# [8360 rows x 22 columns]

# %%
def cause(age_group, metro):   
    #new_df5 = new_df5[new_df5['Value'] < 40]
    df = Death_m_concat_geo[Death_m_concat_geo['Five-Year Age Groups'] == age_group]
    #new_df2['Prop_death'] = new_df2['Prop_death'].apply(lambda x : np.log(x))
    df = df[df['2013 Urbanization'] == metro]
    new_list = [x for x in zip(df['prop_death'],df['Value_sq'])]
    new_list2 = sorted(new_list, key=lambda x: x[1])
    return new_list2

# %%
fig, axes = plt.subplots(2, 2, figsize = (16,16));
axes[0,0].scatter([x[1] for x in cause(62, 'Medium Metro') ],[x[0] for x in cause(62, 'Medium Metro')], 
            label = '60-64',s=6);
axes[1,0].scatter([x[1] for x in cause(67, 'Medium Metro') ],[x[0] for x in cause(67, 'Medium Metro')], 
            label = '65-69',s=6);
axes[0,1].scatter([x[1] for x in cause(72, 'Medium Metro') ],[x[0] for x in cause(72, 'Medium Metro')], 
            label = '70-74', s=6);
axes[1,1].scatter([x[1] for x in cause(77, 'Medium Metro') ],[x[0] for x in cause(77, 'Medium Metro')], 
            label = '75-79', s=6);

axes[0,0].legend();
axes[0,1].legend();
axes[1,0].legend();
axes[1,1].legend();
plt.show();

# %%
X = Death_m_concat_geo[['Comp_Year','Prevalence of Diabetes','Median_Income',
       'All Ages in Poverty Percent', 'Value', 'Value_sq','2013 Urbanization Code','Five-Year Age Groups',
      'Population','prop_death','latitude', 'longitude']]

scaler = MinMaxScaler(feature_range=(0, 1))
X_ = scaler.fit_transform(X)
k_means = cluster.KMeans(n_clusters=80)
X_fit = k_means.fit(X_)
labels = X_fit.labels_
Death_m_concat_geo['clusters'] = labels

# %%
def cause_3(cluster):   
    df = Death_m_concat_geo[Death_m_concat_geo['clusters'] == cluster]
    #new_df5 = new_df5[new_df5['Value'] < 40]
    #new_df2['Prop_death'] = new_df2['Prop_death'].apply(lambda x : np.log(x))
    new_list = [x for x in zip(df['prop_death'],df['Value_sq'])]
    new_list2 = sorted(new_list, key=lambda x: x[1])
    return new_list2

fig, axes = plt.subplots(3, 3, figsize = (16,16), sharey=True, sharex = True);
axes[0,0].scatter([x[1] for x in cause_3(0) ],[x[0] for x in cause_3(0)], 
            label = '0',s=6);
axes[1,0].scatter([x[1] for x in cause_3(1) ],[x[0] for x in cause_3(1)], 
            label = '1',s=6);
axes[2,0].scatter([x[1] for x in cause_3(2) ],[x[0] for x in cause_3(2)], 
            label = '2', s=6);
axes[0,1].scatter([x[1] for x in cause_3(3) ],[x[0] for x in cause_3(3)], 
            label = '3', s=6);
axes[1,1].scatter([x[1] for x in cause_3(4) ],[x[0] for x in cause_3(4)], 
            label = '4', s=6);
axes[2,1].scatter([x[1] for x in cause_3(5) ],[x[0] for x in cause_3(5)], 
            label = '5', s=6);
axes[0,2].scatter([x[1] for x in cause_3(6) ],[x[0] for x in cause_3(6)], 
            label = '6', s=6);
axes[1,2].scatter([x[1] for x in cause_3(7) ],[x[0] for x in cause_3(7)], 
            label = '7', s=6);
axes[2,2].scatter([x[1] for x in cause_3(8) ],[x[0] for x in cause_3(8)], 
            label = '8', s=6);
axes[0,0].legend();
axes[1,0].legend();
axes[2,0].legend();
axes[0,1].legend();
axes[1,1].legend();
axes[2,1].legend();
axes[0,2].legend();
axes[1,2].legend();
axes[2,2].legend();

plt.show();

# %%
A = 40000
B = 50000
C = 10
D = 12
E = 8
F = 10
G = 3.0
H = 77 
I = 77
J = 2015

def cause_3(A,B,C,D,E,F,G,H,I,J):
    Death_Select = Death_m_concat_geo[(Death_m_concat_geo['Median_Income'].between(A, B, inclusive=True) & 
    Death_m_concat_geo['All Ages in Poverty Percent'].between(C, D, inclusive=True) &
    Death_m_concat_geo['Prevalence of Diabetes'].between(E, F, inclusive=False) &
          (Death_m_concat_geo['2013 Urbanization Code'] == G) &
    Death_m_concat_geo['Five-Year Age Groups'].between(H, I, inclusive=True)) &
    (Death_m_concat_geo['Comp_Year'] == J)]
    #new_df5 = new_df5[new_df5['Value'] < 40]
    #new_df2['Prop_death'] = new_df2['Prop_death'].apply(lambda x : np.log(x))
    new_list = [x for x in zip(Death_Select['prop_death'],Death_Select['Value'],
                               Death_Select['County']+" "+Death_Select['State'])]
    new_list2 = sorted(new_list, key=lambda x: x[1])
    return new_list2

fig, ax = plt.subplots(3,2,figsize = (8,8), sharey = True, sharex = True);
ax[0,0].scatter([x[1] for x in cause_3(45000,50000,10,12,8,10,3.0,67,67,2015)],
            [x[0] for x in cause_3(45000,50000,10,12,8,10,3.0,67,67,2015)], 
            label = '0',s=20);

ax[0,1].scatter([x[1] for x in cause_3(40000,45000,13,15,8,10,3.0,77,77,2015)],
           [x[0] for x in cause_3(40000,45000,13,15,8,10,3.0,77,77,2015)], 
            label = '1',s=20);

ax[1,0].scatter([x[1] for x in cause_3(50000,55000,8,10,6,8,3.0,72,72,2012)],
            [x[0] for x in cause_3(50000,55000,8,10,6,8,3.0,72,72,2012)], 
            label = '2',s=20);

ax[1,1].scatter([x[1] for x in cause_3(50000,55000,8,10,7,9,3.0,72,72,2014)],
           [x[0] for x in cause_3(50000,55000,8,10,7,9,3.0,72,72,2014)], 
           label = '3',s=20);

ax[2,0].scatter([x[1] for x in cause_3(40000,45000,15,17,9,11,3.0,67,67,2013)],
           [x[0] for x in cause_3(40000,45000,15,17,9,11,3.0,67,67,2013)], 
           label = '4',s=20);
#for i, txt in enumerate([x[2] for x in cause_3(A,B,C,D,E,F,G,H,I,J)]):
#    ax.annotate(txt, ([x[1] for x in cause_3(A,B,C,D,E,F,G,H,I,J)][i],
#                      [x[0] for x in cause_3(A,B,C,D,E,F,G,H,I,J)][i]),
#      fontsize = 6);

axes[0,0].legend();
axes[0,1].legend();
axes[1,0].legend();
axes[1,1].legend();
axes[2,0].legend();
plt.show();

# %%
plt.figure(figsize = (16,8));
plt.hist(Death_m_concat_geo['Deaths'],bins=2000);
plt.xlim(0,100);
plt.show();

# %%
X_sm = Death_m_concat_geo[['Comp_Year','Prevalence of Diabetes','Median_Income',
       'All Ages in Poverty Percent', 'Value', 'Value_sq','2013 Urbanization Code',
       'latitude', 'longitude','Population','Five-Year Age Groups']]

X_sm_spec = X_sm[(X_sm['Five-Year Age Groups']==77)&
                (X_sm['Population']>=1)&(X_sm['Population']<=10000) &
                (X_sm['Value_sq']>=200)]

y_sm_spec  = Death_m_concat_geo[(Death_m_concat_geo['Five-Year Age Groups']==77)&
                               (Death_m_concat_geo['Population']>=1)&(Death_m_concat_geo['Population']<=10000)
                               & (X_sm['Value_sq']>=200)]

y_sm_spec = y_sm_spec['Deaths']

scaler = MinMaxScaler(feature_range=(0, 1))
X_sm_t = scaler.fit_transform(X_sm_spec)

#X_sm_t = pd.DataFrame(X_sm_t, columns = ["Year","Five-Year Age Groups",'Median_Income',
#                   'All Ages in Poverty Percent','Prevalence of Diabetes',
#'2013 Urbanization Code','Value'])

X_sm_t_new = sm.add_constant(X_sm_t)

sm.GLM(y_sm_spec, X_sm_t_new, family = Poisson()).fit().summary()
# Out:
# /Users/jitsen/anaconda/lib/python3.6/site-packages/statsmodels/base/model.py:1036: RuntimeWarning: invalid value encountered in true_divide
#   return self.params / self.bse
# /Users/jitsen/anaconda/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# /Users/jitsen/anaconda/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# /Users/jitsen/anaconda/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:1818: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= self.a)
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:                 Deaths   No. Observations:                  203
# Model:                            GLM   Df Residuals:                      192
# Model Family:                 Poisson   Df Model:                           10
# Link Function:                    log   Scale:                             1.0
# Method:                          IRLS   Log-Likelihood:                -561.52
# Date:                Tue, 20 Mar 2018   Deviance:                       191.46
# Time:                        14:30:13   Pearson chi2:                     199.
# No. Iterations:                     4
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          2.8833      0.292      9.867      0.000       2.311       3.456
# x1            -0.1200      0.081     -1.490      0.136      -0.278       0.038
# x2             0.5386      0.235      2.289      0.022       0.077       1.000
# x3            -0.7647      0.260     -2.947      0.003      -1.273      -0.256
# x4            -0.6875      0.270     -2.546      0.011      -1.217      -0.158
# x5            -0.6497      2.249     -0.289      0.773      -5.057       3.758
# x6             0.5273      2.320      0.227      0.820      -4.020       5.074
# x7            -0.1415      0.078     -1.814      0.070      -0.294       0.011
# x8            -0.0566      0.096     -0.588      0.557      -0.245       0.132
# x9            -0.1897      0.153     -1.241      0.215      -0.489       0.110
# x10            1.1691      0.084     13.874      0.000       1.004       1.334
# x11                 0          0        nan        nan           0           0
# ==============================================================================
# """

# %%
Death_m_concat_geo_2 = Death_m_concat_geo[Death_m_concat_geo['Five-Year Age Groups']==77]

X_lr_1 = Death_m_concat_geo_2[['Comp_Year','Prevalence of Diabetes','Median_Income',
       'All Ages in Poverty Percent', 'Value', 'Value_sq','2013 Urbanization Code',
       'latitude', 'longitude','Population','Five-Year Age Groups']]

X_lr_2 = Death_m_concat_geo_2[['Comp_Year','Prevalence of Diabetes','Median_Income',
       'All Ages in Poverty Percent','2013 Urbanization Code',
       'latitude', 'longitude','Population','Five-Year Age Groups']]

X_lr_3 = Death_m_concat_geo2[['Value', 'Value_sq']]

y_lr = Death_m_concat_geo_2['Deaths']

scaler = MinMaxScaler(feature_range=(0, 1))

X_lr_t1 = scaler.fit_transform(X_lr_1)
X_lr_t2 = scaler.fit_transform(X_lr_2)
X_lr_t3 = scaler.fit_transform(X_lr_3)

lr1 = LinearRegression()
lr2 = LinearRegression()
lr3 = LinearRegression()

lr1.fit(X_lr_t1, y_lr)
lr2.fit(X_lr_t2, y_lr)
lr3.fit(X_lr_t3, y_lr)

print(lr1.score(X_lr_t1, y_lr),lr2.score(X_lr_t2, y_lr),lr3.score(X_lr_t3, y_lr))
# Out:
# 0.3938209163316939 0.37788985676207876 0.05594090776739402

# %%
X_train, X_test, y_train, y_test = train_test_split(X_sm, Death_m_concat_geo['Deaths'], test_size=0.7)
for i in range(6)[1:]:    
    rand_forest = RandomForestRegressor(n_estimators=5+i, min_samples_split=5*(i))
    rand_forest.fit(X_train, y_train)
    y_test_pred_rand_forest = rand_forest.predict(X_test)
    print(rand_forest.score(X_test,y_test),rand_forest.score(X_train, y_train))
# Out:
# 0.8164093294924285 0.9488071434174759
# 0.7947324920016634 0.9130889005335062
# 0.8145117806910018 0.896673777060939
# 0.8045153456804062 0.8787706788117612
# 0.7743728605955735 0.8562185905352303
